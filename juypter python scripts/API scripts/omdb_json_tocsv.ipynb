# %%
# Script file to grab data using OMDB's api
# After grabing relavent data store into dataframe and save as csv file
# Dependencies
import requests
import pandas as pd
import numpy as np
#from config import api_key
# import api key
api_key = 'trilogy'
# read in csv file for title lis
num_csv = "../data_files/Numberdotcom_fix_names.csv"

# %%
# read in csv file for title list
num_df = pd.read_csv(num_csv)
num_df.head()
# Out:
#    Ranking per year      Released                           Title  \
# 0                 1  Nov 17, 2000  How the Grinch Stole Christmas
# 1                 2  Dec 22, 2000                       Cast Away
# 2                 3  May 24, 2000          Mission: Impossible II
# 3                 4   May 5, 2000                       Gladiator
# 4                 5  Dec 15, 2000                 What Women Want
#
#                               Source Production\nBudget  \
# 0  Based on Fiction Book/Short Story       $123,000,000
# 1                Original Screenplay        $85,000,000
# 2                        Based on TV       $120,000,000
# 3                Original Screenplay       $103,000,000
# 4                Original Screenplay        $65,000,000
#
#   Opening Weekend\nRevenue Domestic\nBox Office Infl. Adj. Dom.\nBox Office  \
# 0              $55,820,330         $260,044,825                $438,980,791
# 1              $28,883,406         $233,632,142                $384,884,272
# 2              $57,845,297         $215,409,889                $364,078,672
# 3              $34,819,017         $187,683,805                $317,130,387
# 4              $33,614,543         $182,805,123                $303,565,725
#
#   International\nBox Office Worldwide\nBox Office
# 0               $85,096,578          $345,141,403
# 1              $193,598,374          $427,230,516
# 2              $334,178,627          $549,588,516
# 3              $270,000,000          $457,683,805
# 4              $191,300,000          $374,105,123

# %%
# generate title list for api seach
titles = num_df['Title'].tolist()
titles[0]
# Set up release date list incase of duplicate title
release = num_df['Released'].tolist()
release
# Out:
# ['Nov 17, 2000',
#  'Dec 22, 2000',
#  'May 24, 2000',
#  'May 5, 2000',
#  'Dec 15, 2000',
#  'Jun 30, 2000',
#  'Oct 6, 2000',
#  'Jul 14, 2000',
#  'Jul 7, 2000',
#  'Jul 21, 2000',
#  'May 19, 2000',
#  'Dec 8, 2000',
#  'Mar 17, 2000',
#  'Nov 3, 2000',
#  'Dec 27, 2000',
#  'Jul 28, 2000',
#  'Jun 2, 2000',
#  'Sep 29, 2000',
#  'Jun 28, 2000',
#  'Dec 22, 2000',
#  'Jun 21, 2000',
#  'Jun 9, 2000',
#  'Nov 22, 2000',
#  'Jun 23, 2000',
#  'Aug 4, 2000',
#  'Dec 15, 2000',
#  'Feb 4, 2000',
#  'Apr 21, 2000',
#  'Nov 17, 2000',
#  'Dec 22, 2000',
#  'Aug 4, 2000',
#  'Dec 15, 2000',
#  'Jun 16, 2000',
#  'Jul 7, 2000',
#  'May 19, 2000',
#  'Dec 8, 2000',
#  'Nov 22, 2000',
#  'Apr 7, 2000',
#  'Aug 18, 2000',
#  'Mar 10, 2000',
#  'Aug 4, 2000',
#  'Feb 18, 2000',
#  'May 26, 2000',
#  'Mar 22, 2000',
#  'Mar 17, 2000',
#  'Dec 19, 2000',
#  'Mar 31, 2000',
#  'Nov 10, 2000',
#  'Feb 11, 2000',
#  'Dec 22, 2000',
#  'Apr 28, 2000',
#  'Aug 11, 2000',
#  'Jul 21, 2000',
#  'Feb 11, 2000',
#  'Nov 10, 2000',
#  'Feb 18, 2000',
#  'Oct 20, 2000',
#  'Aug 11, 2000',
#  'Apr 14, 2000',
#  'Apr 14, 2000',
#  'Nov 17, 2000',
#  'Feb 18, 2000',
#  'Apr 28, 2000',
#  'Mar 31, 2000',
#  'Dec 22, 2000',
#  'Nov 17, 2000',
#  'Apr 28, 2000',
#  'Oct 20, 2000',
#  'Dec 22, 2000',
#  'Apr 7, 2000',
#  'Dec 8, 2000',
#  'Sep 15, 2000',
#  'Nov 3, 2000',
#  'Aug 25, 2000',
#  'Aug 11, 2000',
#  'Sep 8, 2000',
#  'Apr 21, 2000',
#  'Mar 31, 2000',
#  'Oct 27, 2000',
#  'Jun 30, 2000',
#  'Sep 8, 2000',
#  'Feb 25, 2000',
#  'Jun 16, 2000',
#  'Jun 16, 2000',
#  'May 12, 2000',
#  'Sep 22, 2000',
#  'Feb 23, 2000',
#  'Mar 10, 2000',
#  'Nov 10, 2000',
#  'May 19, 2000',
#  'May 12, 2000',
#  'Oct 13, 2000',
#  'Jan 28, 2000',
#  'Jul 26, 2000',
#  'Dec 22, 2000',
#  'Jul 21, 2000',
#  'Mar 3, 2000',
#  'Sep 15, 2000',
#  'Dec 8, 2000',
#  'Mar 3, 2000',
#  'Nov 16, 2001',
#  'Dec 19, 2001',
#  'Nov 2, 2001',
#  'May 18, 2001',
#  'Aug 3, 2001',
#  'May 4, 2001',
#  'May 25, 2001',
#  'Dec 7, 2001',
#  'Jul 18, 2001',
#  'Jul 27, 2001',
#  'Dec 21, 2001',
#  'Feb 9, 2001',
#  'Aug 10, 2001',
#  'Jun 22, 2001',
#  'Jun 15, 2001',
#  'Jun 22, 2001',
#  'Mar 30, 2001',
#  'Dec 28, 2001',
#  'Aug 3, 2001',
#  'Dec 14, 2001',
#  'Aug 10, 2001',
#  'Jul 13, 2001',
#  'Jul 20, 2001',
#  'Jul 4, 2001',
#  'Jun 8, 2001',
#  'Dec 21, 2001',
#  'Jun 29, 2001',
#  'Oct 5, 2001',
#  'Apr 6, 2001',
#  'Apr 13, 2001',
#  'Jul 4, 2001',
#  'Jul 13, 2001',
#  'Nov 9, 2001',
#  'Jun 8, 2001',
#  'Mar 2, 2001',
#  'Feb 16, 2001',
#  'Nov 21, 2001',
#  'Jan 26, 2001',
#  'Nov 30, 2001',
#  'Dec 25, 2001',
#  'May 18, 2001',
#  'Aug 17, 2001',
#  'May 11, 2001',
#  'Jun 1, 2001',
#  'Sep 28, 2001',
#  'Apr 6, 2001',
#  'Dec 14, 2001',
#  'Mar 16, 2001',
#  'Mar 16, 2001',
#  'Aug 13, 2001',
#  'Oct 5, 2001',
#  'Dec 25, 2001',
#  'Nov 2, 2001',
#  'Sep 28, 2001',
#  'Nov 2, 2001',
#  'Oct 26, 2001',
#  'Oct 12, 2001',
#  'Dec 26, 2001',
#  'Mar 23, 2001',
#  'Dec 28, 2001',
#  'Sep 14, 2001',
#  'Jun 8, 2001',
#  'Dec 14, 2001',
#  'Jul 6, 2001',
#  'Nov 21, 2001',
#  'Mar 2, 2001',
#  'Apr 27, 2001',
#  'Jun 1, 2001',
#  'Jul 11, 2001',
#  'Oct 19, 2001',
#  'Aug 24, 2001',
#  'Jan 12, 2001',
#  'Oct 19, 2001',
#  'Jun 27, 2001',
#  'Dec 21, 2001',
#  'Mar 30, 2001',
#  'Apr 11, 2001',
#  'Sep 7, 2001',
#  'Apr 20, 2001',
#  'Aug 17, 2001',
#  'Feb 16, 2001',
#  'Mar 9, 2001',
#  'Sep 28, 2001',
#  'May 18, 2001',
#  'Nov 9, 2001',
#  'Dec 21, 2001',
#  'Oct 5, 2001',
#  'Jan 19, 2001',
#  'Aug 24, 2001',
#  'Feb 9, 2001',
#  'Oct 19, 2001',
#  'Sep 14, 2001',
#  'Sep 7, 2001',
#  'Aug 3, 2001',
#  'Feb 23, 2001',
#  'Oct 26, 2001',
#  'Apr 11, 2001',
#  'Apr 20, 2001',
#  'Aug 10, 2001',
#  'Mar 30, 2001',
#  'May 3, 2002',
#  'Dec 18, 2002',
#  'May 16, 2002',
#  'Nov 15, 2002',
#  'Aug 2, 2002',
#  'Jul 25, 2002',
#  'Jul 3, 2002',
#  'Mar 15, 2002',
#  'Dec 27, 2002',
#  'Dec 25, 2002',
#  'Nov 22, 2002',
#  'Jun 14, 2002',
#  'Jun 21, 2002',
#  'Aug 9, 2002',
#  'Nov 1, 2002',
#  'Jun 21, 2002',
#  'Oct 18, 2002',
#  'Sep 27, 2002',
#  'Jun 28, 2002',
#  'Jun 14, 2002',
#  'May 31, 2002',
#  'Nov 8, 2002',
#  'Jul 12, 2002',
#  'Mar 29, 2002',
#  'Dec 13, 2002',
#  'Dec 20, 2002',
#  'Oct 4, 2002',
#  'Apr 19, 2002',
#  'Aug 7, 2002',
#  'Mar 22, 2002',
#  'Jan 18, 2002',
#  'Mar 1, 2002',
#  'Dec 20, 2002',
#  'Mar 29, 2002',
#  'May 24, 2002',
#  'Feb 15, 2002',
#  'Jun 7, 2002',
#  'May 24, 2002',
#  'Apr 12, 2002',
#  'Dec 13, 2002',
#  'Jul 19, 2002',
#  'Mar 8, 2002',
#  'Dec 13, 2002',
#  'Jan 25, 2002',
#  'May 8, 2002',
#  'Jul 3, 2002',
#  'Sep 27, 2002',
#  'Feb 15, 2002',
#  'Feb 8, 2002',
#  'Dec 13, 2002',
#  'Feb 19, 2002',
#  'Dec 27, 2002',
#  'Apr 5, 2002',
#  'Jan 11, 2002',
#  'Jun 14, 2002',
#  'May 17, 2002',
#  'Aug 2, 2002',
#  'Mar 15, 2002',
#  'Aug 16, 2002',
#  'Dec 20, 2002',
#  'Feb 8, 2002',
#  'May 24, 2002',
#  'May 31, 2002',
#  'Nov 27, 2002',
#  'Mar 15, 2002',
#  'Mar 1, 2002',
#  'Mar 29, 2002',
#  'Jan 25, 2002',
#  'Jul 19, 2002',
#  'Nov 1, 2002',
#  'Dec 27, 2002',
#  'Dec 6, 2002',
#  'Apr 19, 2002',
#  'Feb 22, 2002',
#  'Jul 12, 2002',
#  'Jun 7, 2002',
#  'Oct 25, 2002',
#  'Feb 22, 2002',
#  'Aug 9, 2002',
#  'Oct 11, 2002',
#  'Apr 12, 2002',
#  'Dec 6, 2002',
#  'Sep 6, 2002',
#  'Oct 11, 2002',
#  'Feb 15, 2002',
#  'Feb 8, 2002',
#  'Sep 20, 2002',
#  'Oct 11, 2002',
#  'Jul 17, 2002',
#  'Jul 26, 2002',
#  'Aug 23, 2002',
#  'Oct 11, 2002',
#  'Dec 31, 2002',
#  'Nov 15, 2002',
#  'Nov 27, 2002',
#  'Apr 26, 2002',
#  'Sep 20, 2002',
#  'Sep 13, 2002',
#  'Jun 21, 2002',
#  'Aug 30, 2002',
#  'May 30, 2003',
#  'Dec 17, 2003',
#  'Jul 9, 2003',
#  'May 15, 2003',
#  'May 23, 2003',
#  'May 2, 2003',
#  'Nov 7, 2003',
#  'Jul 1, 2003',
#  'Nov 5, 2003',
#  'Dec 25, 2003',
#  'Jul 18, 2003',
#  'Apr 11, 2003',
#  'Mar 7, 2003',
#  'Jun 20, 2003',
#  'Jun 6, 2003',
#  'Dec 12, 2003',
#  'Jul 25, 2003',
#  'Aug 8, 2003',
#  'Jul 25, 2003',
#  'Dec 5, 2003',
#  'Aug 6, 2003',
#  'Oct 24, 2003',
#  'May 30, 2003',
#  'Feb 7, 2003',
#  'Aug 1, 2003',
#  'May 9, 2003',
#  'Feb 14, 2003',
#  'Nov 21, 2003',
#  'Jun 27, 2003',
#  'Dec 25, 2003',
#  'Nov 14, 2003',
#  'Jul 2, 2003',
#  'Oct 8, 2003',
#  'Aug 15, 2003',
#  'Oct 3, 2003',
#  'Nov 26, 2003',
#  'Feb 21, 2003',
#  'Oct 10, 2003',
#  'Apr 18, 2003',
#  'Jan 17, 2003',
#  'Jul 11, 2003',
#  'Dec 10, 2003',
#  'Jul 25, 2003',
#  'Dec 19, 2003',
#  'Feb 7, 2003',
#  'Nov 26, 2003',
#  'Nov 21, 2003',
#  'Nov 7, 2003',
#  'Aug 15, 2003',
#  'Sep 12, 2003',
#  'Jan 10, 2003',
#  'Dec 25, 2003',
#  'Oct 24, 2003',
#  'Apr 25, 2003',
#  'Sep 19, 2003',
#  'Dec 25, 2003',
#  'Feb 14, 2003',
#  'Sep 26, 2003',
#  'Mar 14, 2003',
#  'Jan 31, 2003',
#  'Mar 7, 2003',
#  'Sep 26, 2003',
#  'May 2, 2003',
#  'Sep 19, 2003',
#  'Oct 3, 2003',
#  'Jun 13, 2003',
#  'Mar 28, 2003',
#  'Oct 10, 2003',
#  'Apr 4, 2003',
#  'Aug 29, 2003',
#  'Oct 10, 2003',
#  'Feb 28, 2003',
#  'Apr 18, 2003',
#  'Mar 14, 2003',
#  'Dec 12, 2003',
#  'Mar 21, 2003',
#  'Mar 28, 2003',
#  'Dec 5, 2003',
#  'Jun 13, 2003',
#  'Jul 18, 2003',
#  'Nov 26, 2003',
#  'Mar 28, 2003',
#  'Apr 4, 2003',
#  'Jul 2, 2003',
#  'Jun 13, 2003',
#  'Apr 16, 2003',
#  'Sep 5, 2003',
#  'Aug 22, 2003',
#  'Nov 14, 2003',
#  'Feb 21, 2003',
#  'Nov 26, 2003',
#  'Nov 21, 2003',
#  'Jan 17, 2003',
#  'Jun 20, 2003',
#  'Jul 18, 2003',
#  'Dec 19, 2003',
#  'Feb 21, 2003',
#  'Apr 25, 2003',
#  'Apr 18, 2003',
#  'Sep 26, 2003',
#  'May 19, 2004',
#  'Jun 30, 2004',
#  'Feb 25, 2004',
#  'Dec 22, 2004',
#  'Nov 5, 2004',
#  'Jun 4, 2004',
#  'Nov 10, 2004',
#  'May 28, 2004',
#  'Jul 23, 2004',
#  'Nov 19, 2004',
#  'Oct 1, 2004',
#  'Jul 16, 2004',
#  'May 14, 2004',
#  'Dec 10, 2004',
#  'Feb 13, 2004',
#  'May 7, 2004',
#  'Dec 17, 2004',
#  'Jun 18, 2004',
#  'Jul 30, 2004',
#  'Dec 17, 2004',
#  'Dec 15, 2004',
#  'Aug 6, 2004',
#  'Aug 11, 2004',
#  'Mar 5, 2004',
#  'Jan 16, 2004',
#  'Apr 30, 2004',
#  'Nov 19, 2004',
#  'Mar 26, 2004',
#  'Jul 9, 2004',
#  'Jun 25, 2004',
#  'Aug 13, 2004',
#  'Apr 23, 2004',
#  'Jun 18, 2004',
#  'Jun 11, 2004',
#  'Oct 29, 2004',
#  'Oct 1, 2004',
#  'Nov 24, 2004',
#  'Oct 22, 2004',
#  'Jun 23, 2004',
#  'Mar 5, 2004',
#  'Sep 24, 2004',
#  'Apr 16, 2004',
#  'Jul 30, 2004',
#  'Feb 6, 2004',
#  'Feb 6, 2004',
#  'Oct 8, 2004',
#  'Apr 2, 2004',
#  'Jun 11, 2004',
#  'Mar 19, 2004',
#  'Aug 20, 2004',
#  'Oct 15, 2004',
#  'Jun 11, 2004',
#  'Apr 23, 2004',
#  'Aug 27, 2004',
#  'Dec 8, 2004',
#  'Jul 7, 2004',
#  'Nov 12, 2004',
#  'Jul 16, 2004',
#  'Dec 22, 2004',
#  'Sep 10, 2004',
#  'Apr 2, 2004',
#  'Dec 25, 2004',
#  'Mar 12, 2004',
#  'Apr 2, 2004',
#  'Dec 29, 2004',
#  'Dec 17, 2004',
#  'Aug 20, 2004',
#  'Nov 12, 2004',
#  'Jul 23, 2004',
#  'Mar 26, 2004',
#  'Sep 17, 2004',
#  'May 28, 2004',
#  'Mar 19, 2004',
#  'Nov 24, 2004',
#  'Dec 3, 2004',
#  'Apr 16, 2004',
#  'Oct 15, 2004',
#  'Sep 10, 2004',
#  'Aug 27, 2004',
#  'Feb 20, 2004',
#  'Nov 12, 2004',
#  'Apr 2, 2004',
#  'Mar 26, 2004',
#  'Feb 27, 2004',
#  'Dec 10, 2004',
#  'Jun 16, 2004',
#  'Dec 22, 2004',
#  'Mar 12, 2004',
#  'Apr 9, 2004',
#  'Apr 9, 2004',
#  'Sep 17, 2004',
#  'Jan 16, 2004',
#  'Dec 17, 2004',
#  'Aug 6, 2004',
#  'Aug 13, 2004',
#  'Jun 25, 2004',
#  'Apr 30, 2004',
#  'Feb 20, 2004',
#  'Nov 12, 2004',
#  'Jan 23, 2004',
#  'May 19, 2005',
#  'Dec 9, 2005',
#  'Nov 18, 2005',
#  'Jun 29, 2005',
#  'Dec 14, 2005',
#  'Jul 15, 2005',
#  'Jun 15, 2005',
#  'Jul 15, 2005',
#  'May 27, 2005',
#  'Jun 10, 2005',
#  'Feb 11, 2005',
#  'May 27, 2005',
#  'Jul 8, 2005',
#  'Nov 4, 2005',
#  'Mar 11, 2005',
#  'Nov 18, 2005',
#  'Mar 4, 2005',
#  'Dec 21, 2005',
#  'Aug 19, 2005',
#  'Sep 23, 2005',
#  'May 13, 2005',
#  'Jan 21, 2005',
#  'Dec 21, 2005',
#  'Aug 5, 2005',
#  'Feb 18, 2005',
#  'Mar 18, 2005',
#  'Sep 9, 2005',
#  'Aug 12, 2005',
#  'Apr 1, 2005',
#  'Apr 22, 2005',
#  'Mar 25, 2005',
#  'Apr 8, 2005',
#  'Jan 14, 2005',
#  'Jun 22, 2005',
#  'Apr 15, 2005',
#  'Jul 29, 2005',
#  'Jun 24, 2005',
#  'Nov 4, 2005',
#  'Jun 3, 2005',
#  'Dec 16, 2005',
#  'Aug 19, 2005',
#  'Dec 9, 2005',
#  'Oct 5, 2005',
#  'Mar 4, 2005',
#  'Nov 23, 2005',
#  'Sep 23, 2005',
#  'May 13, 2005',
#  'Jan 28, 2005',
#  'Apr 29, 2005',
#  'Nov 23, 2005',
#  'Jan 14, 2005',
#  'Mar 24, 2005',
#  'Sep 16, 2005',
#  'Aug 12, 2005',
#  'May 6, 2005',
#  'Dec 23, 2005',
#  'Feb 4, 2005',
#  'Oct 28, 2005',
#  'Jul 29, 2005',
#  'Sep 2, 2005',
#  'Dec 25, 2005',
#  'Apr 8, 2005',
#  'Jun 10, 2005',
#  'Jun 1, 2005',
#  'Nov 11, 2005',
#  'Aug 26, 2005',
#  'Mar 30, 2005',
#  'Nov 11, 2005',
#  'Jul 22, 2005',
#  'Mar 11, 2005',
#  'Aug 31, 2005',
#  'Oct 21, 2005',
#  'Jul 22, 2005',
#  'Feb 18, 2005',
#  'Jul 29, 2005',
#  'May 6, 2005',
#  'Feb 4, 2005',
#  'Sep 23, 2005',
#  'Nov 9, 2005',
#  'Oct 14, 2005',
#  'Nov 23, 2005',
#  'Oct 21, 2005',
#  'Nov 11, 2005',
#  'Apr 29, 2005',
#  'Oct 14, 2005',
#  'Dec 2, 2005',
#  'Sep 30, 2005',
#  'Jul 8, 2005',
#  'May 13, 2005',
#  'Jan 14, 2005',
#  'Mar 18, 2005',
#  'Sep 16, 2005',
#  'Dec 28, 2005',
#  'Oct 7, 2005',
#  'Aug 12, 2005',
#  'Apr 22, 2005',
#  'Jun 24, 2005',
#  'Jan 19, 2005',
#  'Feb 25, 2005',
#  'Aug 19, 2005',
#  'Jul 7, 2006',
#  'Dec 22, 2006',
#  'Jun 9, 2006',
#  'May 26, 2006',
#  'May 19, 2006',
#  'Jun 28, 2006',
#  'Nov 17, 2006',
#  'Mar 31, 2006',
#  'Nov 17, 2006',
#  'Dec 15, 2006',
#  'May 19, 2006',
#  'Aug 4, 2006',
#  'Jun 23, 2006',
#  'May 5, 2006',
#  'Oct 6, 2006',
#  'Nov 3, 2006',
#  'Jun 30, 2006',
#  'Jun 2, 2006',
#  'Dec 15, 2006',
#  'Apr 14, 2006',
#  'Mar 10, 2006',
#  'Mar 24, 2006',
#  'Sep 29, 2006',
#  'Dec 15, 2006',
#  'Feb 10, 2006',
#  'Feb 17, 2006',
#  'Jun 16, 2006',
#  'Jul 14, 2006',
#  'Dec 15, 2006',
#  'Jul 21, 2006',
#  'Aug 4, 2006',
#  'Apr 28, 2006',
#  'Mar 17, 2006',
#  'Aug 9, 2006',
#  'Dec 20, 2006',
#  'Jan 27, 2006',
#  'Nov 3, 2006',
#  'Nov 22, 2006',
#  'Jul 28, 2006',
#  'Dec 8, 2006',
#  'Jun 16, 2006',
#  'Jan 20, 2006',
#  'Mar 10, 2006',
#  'May 12, 2006',
#  'Apr 7, 2006',
#  'Feb 10, 2006',
#  'Jul 14, 2006',
#  'Aug 25, 2006',
#  'Dec 8, 2006',
#  'Sep 30, 2006',
#  'Sep 29, 2006',
#  'Jun 6, 2006',
#  'Feb 10, 2006',
#  'Oct 20, 2006',
#  'Jun 16, 2006',
#  'Jan 13, 2006',
#  'Dec 8, 2006',
#  'Feb 10, 2006',
#  'Feb 17, 2006',
#  'Feb 3, 2006',
#  'Jan 27, 2006',
#  'Apr 21, 2006',
#  'Dec 22, 2006',
#  'Jan 13, 2006',
#  'Jul 21, 2006',
#  'Mar 10, 2006',
#  'Nov 10, 2006',
#  'Aug 18, 2006',
#  'Oct 6, 2006',
#  'Oct 13, 2006',
#  'Sep 15, 2006',
#  'Jan 13, 2006',
#  'Dec 29, 2006',
#  'Dec 1, 2006',
#  'Oct 13, 2006',
#  'Apr 14, 2006',
#  'Mar 3, 2006',
#  'Apr 21, 2006',
#  'Dec 25, 2006',
#  'Nov 22, 2006',
#  'Apr 7, 2006',
#  'Oct 27, 2006',
#  'Aug 18, 2006',
#  'Mar 17, 2006',
#  'Oct 20, 2006',
#  'Apr 28, 2006',
#  'Jun 16, 2006',
#  'Jul 28, 2006',
#  'Apr 28, 2006',
#  'Sep 8, 2006',
#  'Mar 24, 2006',
#  'Sep 15, 2006',
#  'Jul 21, 2006',
#  'Apr 7, 2006',
#  'Mar 31, 2006',
#  'Oct 20, 2006',
#  'Aug 11, 2006',
#  'Aug 25, 2006',
#  'Oct 13, 2006',
#  'Mar 3, 2006',
#  'May 4, 2007',
#  'May 17, 2007',
#  'Jul 2, 2007',
#  'May 24, 2007',
#  'Jul 11, 2007',
#  'Dec 14, 2007',
#  'Aug 3, 2007',
#  'Dec 14, 2007',
#  'Mar 9, 2007',
#  'Jun 29, 2007',
#  'Jul 27, 2007',
#  'Mar 2, 2007',
#  'Jun 1, 2007',
#  'Aug 10, 2007',
#  'Jun 27, 2007',
#  'Jun 15, 2007',
#  'Nov 2, 2007',
#  'Nov 21, 2007',
#  'Nov 2, 2007',
#  'Aug 17, 2007',
#  'Jul 20, 2007',
#  'Jul 20, 2007',
#  'Mar 30, 2007',
#  'Jun 8, 2007',
#  'Feb 16, 2007',
#  'Jun 22, 2007',
#  'Dec 25, 2007',
#  'Sep 28, 2007',
#  'Nov 16, 2007',
#  'Feb 16, 2007',
#  'Apr 13, 2007',
#  'Nov 9, 2007',
#  'Jun 22, 2007',
#  'Dec 7, 2007',
#  'Dec 21, 2007',
#  'Jun 8, 2007',
#  'Aug 31, 2007',
#  'Oct 12, 2007',
#  'Mar 23, 2007',
#  'Dec 21, 2007',
#  'Sep 7, 2007',
#  'Dec 7, 2007',
#  'Sep 21, 2007',
#  'Feb 14, 2007',
#  'Oct 5, 2007',
#  'Mar 16, 2007',
#  'Sep 28, 2007',
#  'Mar 23, 2007',
#  'Jul 3, 2007',
#  'Jul 27, 2007',
#  'Feb 2, 2007',
#  'Dec 25, 2007',
#  'Dec 25, 2007',
#  'Dec 26, 2007',
#  'Jan 26, 2007',
#  'Nov 21, 2007',
#  'Oct 19, 2007',
#  'Aug 10, 2007',
#  'Sep 14, 2007',
#  'Jan 5, 2007',
#  'Jan 26, 2007',
#  'Feb 2, 2007',
#  'Feb 23, 2007',
#  'Sep 21, 2007',
#  'Aug 24, 2007',
#  'Mar 2, 2007',
#  'Nov 21, 2007',
#  'Dec 25, 2007',
#  'May 11, 2007',
#  'Oct 12, 2007',
#  'Feb 9, 2007',
#  'Jun 15, 2007',
#  'Apr 5, 2007',
#  'Apr 6, 2007',
#  'Sep 14, 2007',
#  'Apr 20, 2007',
#  'Aug 24, 2007',
#  'Mar 23, 2007',
#  'Oct 19, 2007',
#  'Mar 23, 2007',
#  'May 11, 2007',
#  'Aug 3, 2007',
#  'Sep 21, 2007',
#  'Dec 21, 2007',
#  'Apr 27, 2007',
#  'Sep 14, 2007',
#  'Mar 16, 2007',
#  'Oct 12, 2007',
#  'Jan 5, 2007',
#  'Dec 14, 2007',
#  'Jan 12, 2007',
#  'Aug 17, 2007',
#  'Nov 9, 2007',
#  'Aug 3, 2007',
#  'Sep 7, 2007',
#  'Jun 29, 2007',
#  'Sep 21, 2007',
#  'Sep 14, 2007',
#  'Jun 8, 2007',
#  'Oct 19, 2007',
#  'Jul 18, 2008',
#  'May 2, 2008',
#  'May 22, 2008',
#  'Jul 1, 2008',
#  'Jun 27, 2008',
#  'Jun 6, 2008',
#  'Nov 21, 2008',
#  'Nov 7, 2008',
#  'Nov 14, 2008',
#  'Mar 14, 2008',
#  'May 30, 2008',
#  'Dec 12, 2008',
#  'Jul 18, 2008',
#  'Dec 25, 2008',
#  'May 16, 2008',
#  'Jun 13, 2008',
#  'Jun 27, 2008',
#  'Jun 20, 2008',
#  'Dec 25, 2008',
#  'Nov 26, 2008',
#  'Nov 21, 2008',
#  'Aug 13, 2008',
#  'Dec 25, 2008',
#  'Aug 1, 2008',
#  'Jul 11, 2008',
#  'Sep 26, 2008',
#  'Jul 25, 2008',
#  'Jun 6, 2008',
#  'Dec 19, 2008',
#  'Mar 7, 2008',
#  'Oct 3, 2008',
#  'Aug 6, 2008',
#  'Dec 25, 2008',
#  'Mar 28, 2008',
#  'May 9, 2008',
#  'Feb 14, 2008',
#  'Jan 18, 2008',
#  'Dec 12, 2008',
#  'Jan 18, 2008',
#  'Jul 11, 2008',
#  'Feb 22, 2008',
#  'Feb 14, 2008',
#  'Feb 8, 2008',
#  'Dec 19, 2008',
#  'Nov 7, 2008',
#  'Jun 13, 2008',
#  'Apr 18, 2008',
#  'Apr 25, 2008',
#  'Sep 12, 2008',
#  'Feb 14, 2008',
#  'Apr 18, 2008',
#  'Dec 19, 2008',
#  'Nov 26, 2008',
#  'Aug 22, 2008',
#  'Apr 4, 2008',
#  'May 2, 2008',
#  'Aug 6, 2008',
#  'May 9, 2008',
#  'Apr 11, 2008',
#  'Jan 25, 2008',
#  'Feb 8, 2008',
#  'Mar 21, 2008',
#  'Oct 17, 2008',
#  'Sep 12, 2008',
#  'Oct 10, 2008',
#  'Sep 19, 2008',
#  'Jan 25, 2008',
#  'Aug 22, 2008',
#  'Oct 24, 2008',
#  'Dec 10, 2008',
#  'Feb 29, 2008',
#  'Dec 12, 2008',
#  'Mar 21, 2008',
#  'Jun 20, 2008',
#  'Nov 26, 2008',
#  'Nov 26, 2008',
#  'Oct 31, 2008',
#  'Apr 4, 2008',
#  'Aug 15, 2008',
#  'Jul 18, 2008',
#  'Mar 7, 2008',
#  'Jan 25, 2008',
#  'Sep 12, 2008',
#  'Jan 4, 2008',
#  'Feb 29, 2008',
#  'Mar 28, 2008',
#  'Apr 11, 2008',
#  'Oct 17, 2008',
#  'Mar 14, 2008',
#  'Aug 27, 2008',
#  'Aug 15, 2008',
#  'Dec 26, 2008',
#  'Aug 29, 2008',
#  'Jul 25, 2008',
#  'Jan 18, 2008',
#  'Sep 19, 2008',
#  'Dec 25, 2008',
#  'Sep 19, 2008',
#  'Sep 19, 2008',
#  'Dec 5, 2008',
#  'Dec 18, 2009',
#  'Jun 24, 2009',
#  'Jul 15, 2009',
#  'Nov 20, 2009',
#  'May 29, 2009',
#  'Jun 5, 2009',
#  'May 8, 2009',
#  'Nov 20, 2009',
#  'Dec 23, 2009',
#  'Dec 25, 2009',
#  'Mar 27, 2009',
#  'Jul 1, 2009',
#  'May 1, 2009',
#  'May 22, 2009',
#  'Nov 13, 2009',
#  'Jun 19, 2009',
#  'Apr 3, 2009',
#  'Aug 7, 2009',
#  'Jan 16, 2009',
#  'Jan 30, 2009',
#  'Nov 6, 2009',
#  'May 15, 2009',
#  'May 21, 2009',
#  'Sep 18, 2009',
#  'Aug 21, 2009',
#  'Jul 24, 2009',
#  'Aug 14, 2009',
#  'Dec 25, 2009',
#  'Oct 9, 2009',
#  'Mar 6, 2009',
#  'Nov 25, 2009',
#  'Jul 1, 2009',
#  'Aug 7, 2009',
#  'Feb 6, 2009',
#  'Feb 20, 2009',
#  'Jul 24, 2009',
#  'Dec 4, 2009',
#  'Mar 20, 2009',
#  'Apr 10, 2009',
#  'Oct 16, 2009',
#  'Oct 2, 2009',
#  'Feb 6, 2009',
#  'Oct 16, 2009',
#  'Jan 16, 2009',
#  'Oct 28, 2009',
#  'Mar 20, 2009',
#  'Apr 24, 2009',
#  'Mar 13, 2009',
#  'Aug 28, 2009',
#  'Jun 12, 2009',
#  'Feb 13, 2009',
#  'Apr 17, 2009',
#  'Aug 14, 2009',
#  'Jul 10, 2009',
#  'Jan 9, 2009',
#  'Jul 31, 2009',
#  'Sep 11, 2009',
#  'Nov 25, 2009',
#  'Jun 5, 2009',
#  'Jun 26, 2009',
#  'Jan 23, 2009',
#  'Dec 11, 2009',
#  'Jun 19, 2009',
#  'Jan 9, 2009',
#  'Nov 20, 2009',
#  'May 29, 2009',
#  'Jul 24, 2009',
#  'Mar 20, 2009',
#  'Sep 25, 2009',
#  'Nov 25, 2009',
#  'Dec 11, 2009',
#  'Apr 17, 2009',
#  'Jan 16, 2009',
#  'Sep 4, 2009',
#  'Aug 28, 2009',
#  'Sep 18, 2009',
#  'Mar 13, 2009',
#  'Nov 6, 2009',
#  'Apr 22, 2009',
#  'Apr 24, 2009',
#  'Feb 6, 2009',
#  'Sep 9, 2009',
#  'Dec 18, 2009',
#  'Oct 16, 2009',
#  'Jan 16, 2009',
#  'Dec 4, 2009',
#  'May 22, 2009',
#  'Feb 13, 2009',
#  'Jul 31, 2009',
#  'Apr 10, 2009',
#  'Apr 24, 2009',
#  'Sep 18, 2009',
#  'Sep 25, 2009',
#  'Nov 13, 2009',
#  'Aug 21, 2009',
#  'Sep 4, 2009',
#  'Dec 18, 2009',
#  'Oct 23, 2009',
#  'Oct 2, 2009',
#  'Jan 23, 2009',
#  ...]

# %%
# test run
url = f"http://www.omdbapi.com/?apikey={api_key}&t="
response = requests.get(url + titles[0]).json()

# %%
# looking at json
response
# Out:
# {'Title': 'How the Grinch Stole Christmas',
#  'Year': '2000',
#  'Rated': 'PG',
#  'Released': '17 Nov 2000',
#  'Runtime': '104 min',
#  'Genre': 'Comedy, Family, Fantasy',
#  'Director': 'Ron Howard',
#  'Writer': 'Dr. Seuss (book), Jeffrey Price (screenplay), Peter S. Seaman (screenplay)',
#  'Actors': 'Jim Carrey, Taylor Momsen, Kelley, Jeffrey Tambor',
#  'Plot': 'On the outskirts of Whoville lives a green, revenge-seeking Grinch who plans to ruin Christmas for all of the citizens of the town.',
#  'Language': 'English',
#  'Country': 'USA',
#  'Awards': 'Won 1 Oscar. Another 17 wins & 37 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWNiNTczNzEtMjQyZC00MjFmLTkzMDMtODk4ZGMyZmE0N2E4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '50%'},
#   {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Metascore': '46',
#  'imdbRating': '6.1',
#  'imdbVotes': '193,860',
#  'imdbID': 'tt0170016',
#  'Type': 'movie',
#  'DVD': '20 Nov 2001',
#  'BoxOffice': '$259,011,600',
#  'Production': 'Universal Pictures',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
# empty lists for dataframe construction
ratings=[]
awards=[]
rated=[]
runtime=[]
genre=[]
metascore=[]
imdbRating=[]
imdbVotes=[]
imdbID=[]
titles_edit=[]
responses=[]
release_edit=[]

# %%
# forloop for api call, limit to 1000 calls a day
for i in range(0,900):
    response = requests.get(url + titles[i]).json()
    responses.append(response)
    try:
        ratings.append(response['Ratings'])
        awards.append(response['Awards'])
        rated.append(response['Rated'])
        runtime.append(response['Runtime'])
        genre.append(response['Genre'])
        metascore.append(response['Metascore'])
        imdbRating.append(response['imdbRating'])
        imdbVotes.append(response['imdbVotes'])
        imdbID.append (response['imdbID'])
        titles_edit.append(titles[i])
        release_edit.append(release[i])
    except:
        print(f"Movie not found, title={titles[i]}")
# Out:
# Movie not found, title=Love and Basketball
# Movie not found, title=Don’t Say a Word
# Movie not found, title=Thirteen Ghosts
# Movie not found, title=The Divine Secrets of the Ya-Ya Sisterhood
# Movie not found, title=Peter Pan 2: Return to Neverland
# Movie not found, title=AVP: Alien Vs. Predator
# Movie not found, title=Miss Congeniality 2: Armed and Fabulous
# Movie not found, title=Danny the Dog
# Movie not found, title=2 For the Money
# Movie not found, title=George A. Romero's Land of the Dead
# Movie not found, title=Barnyard: The Original Party Animals
# Movie not found, title=El Laberinto del Fauno
# Movie not found, title=The Hills Have Eyes II
# Movie not found, title=Arthur et les Minimoys

# %%
# Testing cell
len(titles_edit)
# Out:
# 888

# %%
len(imdbID)
# Out:
# 888

# %%
# Create dataframe from api data
omdb_df =pd.DataFrame({'Title':titles_edit,
                        'Released':release_edit,
                        'ratings':ratings,
                        'awards':awards,
                        'rated':rated,
                        'runtime':runtime,
                        'genere':genre,
                        'metascore':metascore,
                        'imdbRating':imdbRating,
                        'imdbVotes':imdbVotes,
                        'imdbID':imdbID})
omdb_df
# Out:
#                                      Title      Released  \
# 0           How the Grinch Stole Christmas  Nov 17, 2000
# 1                                Cast Away  Dec 22, 2000
# 2                   Mission: Impossible II  May 24, 2000
# 3                                Gladiator   May 5, 2000
# 4                          What Women Want  Dec 15, 2000
# ..                                     ...           ...
# 883                                   Igor  Sep 19, 2008
# 884                  My Best Friend's Girl  Sep 19, 2008
# 885                            Frost/Nixon   Dec 5, 2008
# 886                     Alien vs. Predator  Aug 13, 2004
# 887  Miss Congeniality 2: Armed & Fabulous  Mar 24, 2005
#
#                                                ratings  \
# 0    [{'Source': 'Internet Movie Database', 'Value'...
# 1    [{'Source': 'Internet Movie Database', 'Value'...
# 2    [{'Source': 'Internet Movie Database', 'Value'...
# 3    [{'Source': 'Internet Movie Database', 'Value'...
# 4    [{'Source': 'Internet Movie Database', 'Value'...
# ..                                                 ...
# 883  [{'Source': 'Internet Movie Database', 'Value'...
# 884  [{'Source': 'Internet Movie Database', 'Value'...
# 885  [{'Source': 'Internet Movie Database', 'Value'...
# 886  [{'Source': 'Internet Movie Database', 'Value'...
# 887  [{'Source': 'Internet Movie Database', 'Value'...
#
#                                                 awards  rated  runtime  \
# 0       Won 1 Oscar. Another 17 wins & 37 nominations.     PG  104 min
# 1    Nominated for 2 Oscars. Another 15 wins & 35 n...  PG-13  143 min
# 2                            12 wins & 20 nominations.  PG-13  123 min
# 3     Won 5 Oscars. Another 54 wins & 104 nominations.      R  155 min
# 4    Nominated for 1 Golden Globe. Another 5 wins &...  PG-13  127 min
# ..                                                 ...    ...      ...
# 883                                      1 nomination.     PG   87 min
# 884                                      1 nomination.      R  101 min
# 885  Nominated for 5 Oscars. Another 23 wins & 74 n...      R  122 min
# 886                            2 wins & 4 nominations.  PG-13  101 min
# 887                            2 wins & 5 nominations.  PG-13  115 min
#
#                                           genere metascore imdbRating  \
# 0                        Comedy, Family, Fantasy        46        6.1
# 1                      Adventure, Drama, Romance        73        7.8
# 2                    Action, Adventure, Thriller        59        6.1
# 3                       Action, Adventure, Drama        67        8.5
# 4                       Comedy, Fantasy, Romance        47        6.4
# ..                                           ...       ...        ...
# 883           Animation, Comedy, Family, Fantasy        40        6.0
# 884                              Comedy, Romance        34        5.9
# 885                    Biography, Drama, History        80        7.7
# 886  Action, Adventure, Horror, Sci-Fi, Thriller        29        5.6
# 887                        Action, Comedy, Crime        34        5.1
#
#      imdbVotes     imdbID
# 0      193,860  tt0170016
# 1      491,190  tt0162222
# 2      299,689  tt0120755
# 3    1,265,367  tt0172495
# 4      184,860  tt0207201
# ..         ...        ...
# 883     21,758  tt0465502
# 884     41,515  tt1046163
# 885     98,657  tt0870111
# 886    178,257  tt0370263
# 887     66,134  tt0385307
#
# [888 rows x 11 columns]

# %%
# A quick parsing script to extract nominations in int form
nom_list=[]
x=0
for index, row in omdb_df.iterrows():
    mov=row['awards']
    try:
        award=str(mov)
        end=award.find('nominations')
        if end == -1:
            nom_list.append(np.nan)
            x +=1
        else:
            start=award[:end-1].rfind(' ')
            nom_list.append(award[start+1:end-1])
    except:
        print('error')
#add to df
omdb_df["nominations"]=nom_list
omdb_df.head()
# Out:
#                             Title      Released  \
# 0  How the Grinch Stole Christmas  Nov 17, 2000
# 1                       Cast Away  Dec 22, 2000
# 2          Mission: Impossible II  May 24, 2000
# 3                       Gladiator   May 5, 2000
# 4                 What Women Want  Dec 15, 2000
#
#                                              ratings  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...
# 1  [{'Source': 'Internet Movie Database', 'Value'...
# 2  [{'Source': 'Internet Movie Database', 'Value'...
# 3  [{'Source': 'Internet Movie Database', 'Value'...
# 4  [{'Source': 'Internet Movie Database', 'Value'...
#
#                                               awards  rated  runtime  \
# 0     Won 1 Oscar. Another 17 wins & 37 nominations.     PG  104 min
# 1  Nominated for 2 Oscars. Another 15 wins & 35 n...  PG-13  143 min
# 2                          12 wins & 20 nominations.  PG-13  123 min
# 3   Won 5 Oscars. Another 54 wins & 104 nominations.      R  155 min
# 4  Nominated for 1 Golden Globe. Another 5 wins &...  PG-13  127 min
#
#                         genere metascore imdbRating  imdbVotes     imdbID  \
# 0      Comedy, Family, Fantasy        46        6.1    193,860  tt0170016
# 1    Adventure, Drama, Romance        73        7.8    491,190  tt0162222
# 2  Action, Adventure, Thriller        59        6.1    299,689  tt0120755
# 3     Action, Adventure, Drama        67        8.5  1,265,367  tt0172495
# 4     Comedy, Fantasy, Romance        47        6.4    184,860  tt0207201
#
#   nominations
# 0          37
# 1          35
# 2          20
# 3         104
# 4           8

# %%
omdb_df.to_csv('../data_files/first900_fix.csv')
